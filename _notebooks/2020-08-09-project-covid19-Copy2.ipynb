# %% [markdown]
# # Data Analysis for Covid19 JHU data

# %%
#collapse-hide
import altair as alt
import os
import numpy as np
import pandas as pd
import matplotlib
from IPython.display import display, Markdown
from collections import defaultdict
from datetime import datetime, timedelta, date
import scipy as sci
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pycountry_convert as pc
import folium
import branca
from scipy.interpolate import make_interp_spline, BSpline
import plotly.express as px
import json, requests
from keras.layers import Input, Dense, Activation, LeakyReLU, Dropout
from keras import models
from keras.optimizers import RMSprop, Adam
from folium import plugins
from IPython.display import HTML
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import ticker
import calmap

# %config InlineBackend.figure_format = 'retina'

chart_width = 550
chart_height= 400
# Out:
# Using TensorFlow backend.

# %%
#collapse-hide
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

df_covid19 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv")
df_table = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_time.csv",parse_dates=['Last_Update'])

# %%
#collapse-hide
df_covid19 = df_covid19.drop(["People_Tested","People_Hospitalized","UID","ISO3","Mortality_Rate"],axis =1)
df_confirmed = df_confirmed.rename(columns={"Province/State":"state","Country/Region": "country"})
df_deaths = df_deaths.rename(columns={"Province/State":"state","Country/Region": "country"})
df_covid19 = df_covid19.rename(columns={"Country_Region": "country"})
df_covid19["Active"] = df_covid19["Confirmed"]-df_covid19["Recovered"]-df_covid19["Deaths"]
# Changing the conuntry names as required by pycountry_convert Lib
df_confirmed.loc[df_confirmed['country'] == "US", "country"] = "USA"
df_deaths.loc[df_deaths['country'] == "US", "country"] = "USA"
df_covid19.loc[df_covid19['country'] == "US", "country"] = "USA"
df_table.loc[df_table['Country_Region'] == "US", "Country_Region"] = "USA"
# df_recovered.loc[df_recovered['country'] == "US", "country"] = "USA"


df_confirmed.loc[df_confirmed['country'] == 'Korea, South', "country"] = 'South Korea'
df_deaths.loc[df_deaths['country'] == 'Korea, South', "country"] = 'South Korea'
df_covid19.loc[df_covid19['country'] == "Korea, South", "country"] = "South Korea"
df_table.loc[df_table['Country_Region'] == "Korea, South", "Country_Region"] = "South Korea"
# df_recovered.loc[df_recovered['country'] == 'Korea, South', "country"] = 'South Korea'

df_confirmed.loc[df_confirmed['country'] == 'Taiwan*', "country"] = 'Taiwan'
df_deaths.loc[df_deaths['country'] == 'Taiwan*', "country"] = 'Taiwan'
df_covid19.loc[df_covid19['country'] == "Taiwan*", "country"] = "Taiwan"
df_table.loc[df_table['Country_Region'] == "Taiwan*", "Country_Region"] = "Taiwan"
# df_recovered.loc[df_recovered['country'] == 'Taiwan*', "country"] = 'Taiwan'

df_confirmed.loc[df_confirmed['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'
df_deaths.loc[df_deaths['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'
df_covid19.loc[df_covid19['country'] == "Congo (Kinshasa)", "country"] = "Democratic Republic of the Congo"
df_table.loc[df_table['Country_Region'] == "Congo (Kinshasa)", "Country_Region"] = "Democratic Republic of the Congo"
# df_recovered.loc[df_recovered['country'] == 'Congo (Kinshasa)', "country"] = 'Democratic Republic of the Congo'

df_confirmed.loc[df_confirmed['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_deaths.loc[df_deaths['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_covid19.loc[df_covid19['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"
df_table.loc[df_table['Country_Region'] == "Cote d'Ivoire", "Country_Region"] = "Côte d'Ivoire"
# df_recovered.loc[df_recovered['country'] == "Cote d'Ivoire", "country"] = "Côte d'Ivoire"

df_confirmed.loc[df_confirmed['country'] == "Reunion", "country"] = "Réunion"
df_deaths.loc[df_deaths['country'] == "Reunion", "country"] = "Réunion"
df_covid19.loc[df_covid19['country'] == "Reunion", "country"] = "Réunion"
df_table.loc[df_table['Country_Region'] == "Reunion", "Country_Region"] = "Réunion"
# df_recovered.loc[df_recovered['country'] == "Reunion", "country"] = "Réunion"

df_confirmed.loc[df_confirmed['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'
df_deaths.loc[df_deaths['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'
df_covid19.loc[df_covid19['country'] == "Congo (Brazzaville)", "country"] = "Republic of the Congo"
df_table.loc[df_table['Country_Region'] == "Congo (Brazzaville)", "Country_Region"] = "Republic of the Congo"
# df_recovered.loc[df_recovered['country'] == 'Congo (Brazzaville)', "country"] = 'Republic of the Congo'

df_confirmed.loc[df_confirmed['country'] == 'Bahamas, The', "country"] = 'Bahamas'
df_deaths.loc[df_deaths['country'] == 'Bahamas, The', "country"] = 'Bahamas'
df_covid19.loc[df_covid19['country'] == "Bahamas, The", "country"] = "Bahamas"
df_table.loc[df_table['Country_Region'] == "Bahamas, The", "Country_Region"] = "Bahamas"
# df_recovered.loc[df_recovered['country'] == 'Bahamas, The', "country"] = 'Bahamas'

df_confirmed.loc[df_confirmed['country'] == 'Gambia, The', "country"] = 'Gambia'
df_deaths.loc[df_deaths['country'] == 'Gambia, The', "country"] = 'Gambia'
df_covid19.loc[df_covid19['country'] == "Gambia, The", "country"] = "Gambia"
df_table.loc[df_table['Country_Region'] == "Gambia", "Country_Region"] = "Gambia"
# df_recovered.loc[df_recovered['country'] == 'Gambia, The', "country"] = 'Gambia'

# %%
#collapse-hide
# getting all countries
countries = np.asarray(df_confirmed["country"])
countries1 = np.asarray(df_covid19["country"])
# Continent_code to Continent_names
continents = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU' : 'Europe',
    'na' : 'Others'
}

# Defininng Function for getting continent code for country.
def country_to_continent_code(country):
    try:
        return pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(country))
    except :
        return 'na'

#Collecting Continent Information
df_confirmed.insert(2,"continent", [continents[country_to_continent_code(country)] for country in countries[:]])
df_deaths.insert(2,"continent",  [continents[country_to_continent_code(country)] for country in countries[:]])
df_covid19.insert(1,"continent",  [continents[country_to_continent_code(country)] for country in countries1[:]])
df_table.insert(1,"continent",  [continents[country_to_continent_code(country)] for country in df_table["Country_Region"].values])

# %%
#collapse-hide
df_table = df_table[df_table["continent"] != "Others"]
df_confirmed = df_confirmed.replace(np.nan, '', regex=True)
df_deaths = df_deaths.replace(np.nan, '', regex=True)

# %%
#collapse-hide
df_countries_cases = df_covid19.copy().drop(['Lat','Long_','continent','Last_Update'],axis =1)
df_countries_cases.index = df_countries_cases["country"]
df_countries_cases = df_countries_cases.drop(['country'],axis=1)

df_continents_cases = df_covid19.copy().drop(['Lat','Long_','country','Last_Update'],axis =1)
df_continents_cases = df_continents_cases.groupby(["continent"]).sum()

df_countries_cases.fillna(0,inplace=True)
df_continents_cases.fillna(0,inplace=True)

# %%
#collapse-hide
df_t = pd.DataFrame(pd.to_numeric(df_countries_cases.sum()),dtype=np.float64).transpose()
df_t["Mortality Rate (per 100)"] = np.round(100*df_t["Deaths"]/df_t["Confirmed"],2)
df_t.style.background_gradient(cmap='Wistia',axis=1).format("{:.2f}").format("{:.0f}",subset=["Confirmed","Deaths","Recovered","Active"])
# Out:
# <style  type="text/css" >
#     #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col0 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col1 {
#             background-color:  #e8fc6c;
#             color:  #000000;
#         }    #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col2 {
#             background-color:  #ffaf00;
#             color:  #000000;
#         }    #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col3 {
#             background-color:  #ffd911;
#             color:  #000000;
#         }    #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col4 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_b99c355c_dc73_11ea_983e_f49634a60198row0_col5 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }</style><table id="T_b99c355c_dc73_11ea_983e_f49634a60198" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>        <th class="col_heading level0 col4" >Incident_Rate</th>        <th class="col_heading level0 col5" >Mortality Rate (per 100)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b99c355c_dc73_11ea_983e_f49634a60198level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col0" class="data row0 col0" >20295343</td>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col1" class="data row0 col1" >741423</td>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col2" class="data row0 col2" >12592114</td>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col3" class="data row0 col3" >6856598</td>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col4" class="data row0 col4" >61500.08</td>
#                         <td id="T_b99c355c_dc73_11ea_983e_f49634a60198row0_col5" class="data row0 col5" >3.65</td>
#             </tr>
#     </tbody></table>

# %%
#collapse-hide
df_continents_cases["Mortality Rate (per 100)"] = np.round(100*df_continents_cases["Deaths"]/df_continents_cases["Confirmed"],2)
df_continents_cases.style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Reds',subset=["Deaths"])\
                        .background_gradient(cmap='Greens',subset=["Recovered"])\
                        .background_gradient(cmap='Purples',subset=["Active"])\
                        .background_gradient(cmap='Pastel1_r',subset=["Incident_Rate"])\
                        .background_gradient(cmap='YlOrBr',subset=["Mortality Rate (per 100)"])\
                        .format("{:.2f}")\
                        .format("{:.0f}",subset=["Confirmed","Deaths","Recovered","Active"])
# Out:
# <style  type="text/css" >
#     #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col0 {
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col1 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col2 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col3 {
#             background-color:  #f4f2f8;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col4 {
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col5 {
#             background-color:  #fff7bc;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col0 {
#             background-color:  #0c56a0;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col1 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col3 {
#             background-color:  #c8c8e2;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col4 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col5 {
#             background-color:  #fff8c1;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row2_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col0 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col1 {
#             background-color:  #a30f15;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col2 {
#             background-color:  #88ce87;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col3 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col4 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row3_col5 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col2 {
#             background-color:  #48ae60;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row4_col5 {
#             background-color:  #fead3a;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col4 {
#             background-color:  #fddaec;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row5_col5 {
#             background-color:  #ffeea8;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col0 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col1 {
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col2 {
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col3 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_b9ab7414_dc73_11ea_9f11_f49634a60198row6_col5 {
#             background-color:  #fecb5f;
#             color:  #000000;
#         }</style><table id="T_b9ab7414_dc73_11ea_9f11_f49634a60198" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>        <th class="col_heading level0 col4" >Incident_Rate</th>        <th class="col_heading level0 col5" >Mortality Rate (per 100)</th>    </tr>    <tr>        <th class="index_name level0" >continent</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b9ab7414_dc73_11ea_9f11_f49634a60198level0_row0" class="row_heading level0 row0" >Africa</th>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col0" class="data row0 col0" >1061880</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col1" class="data row0 col1" >23804</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col2" class="data row0 col2" >756445</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col3" class="data row0 col3" >281631</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col4" class="data row0 col4" >5255.89</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row0_col5" class="data row0 col5" >2.24</td>
#             </tr>
#             <tr>
#                         <th id="T_b9ab7414_dc73_11ea_9f11_f49634a60198level0_row1" class="row_heading level0 row1" >Asia</th>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col0" class="data row1 col0" >5197692</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col1" class="data row1 col1" >112413</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col2" class="data row1 col2" >3953190</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col3" class="data row1 col3" >1132089</td>
#                         <td id="T_b9ab7414_dc73_11ea_9f11_f49634a60198row1_col4" class="data row1 col4" >19670.71</td>

# %%
#collapse-hide
df_countries_cases["Mortality Rate (per 100)"] = np.round(100*df_countries_cases["Deaths"]/df_countries_cases["Confirmed"],2)
df_countries_cases.sort_values('Confirmed', ascending= False).style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Reds',subset=["Deaths"])\
                        .background_gradient(cmap='Greens',subset=["Recovered"])\
                        .background_gradient(cmap='Purples',subset=["Active"])\
                        .background_gradient(cmap='Pastel1_r',subset=["Incident_Rate"])\
                        .background_gradient(cmap='YlOrBr',subset=["Mortality Rate (per 100)"])\
                        .format("{:.2f}")\
                        .format("{:.0f}",subset=["Confirmed","Deaths","Recovered","Active"])
# Out:
# <style  type="text/css" >
#     #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col2 {
#             background-color:  #2f974e;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row0_col5 {
#             background-color:  #fff8c1;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col0 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col1 {
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col3 {
#             background-color:  #eae9f3;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row1_col5 {
#             background-color:  #fff8c0;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col0 {
#             background-color:  #7db8da;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col1 {
#             background-color:  #fcb296;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col2 {
#             background-color:  #369f54;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col3 {
#             background-color:  #e3e2ef;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row2_col5 {
#             background-color:  #fffbcf;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col0 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col1 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col2 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col3 {
#             background-color:  #f6f5f9;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col4 {
#             background-color:  #fddaec;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row3_col5 {
#             background-color:  #fffbd2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col0 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col2 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col3 {
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col4 {
#             background-color:  #e5d8bd;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row4_col5 {
#             background-color:  #fffbcf;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col0 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col1 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col2 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col3 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row5_col5 {
#             background-color:  #fec14c;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col0 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col1 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col2 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col3 {
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col4 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row6_col5 {
#             background-color:  #fff3b2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col0 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col1 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col2 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col3 {
#             background-color:  #f7f5fa;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col4 {
#             background-color:  #fddaec;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row7_col5 {
#             background-color:  #fff8c0;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col2 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col4 {
#             background-color:  #fed9a6;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row8_col5 {
#             background-color:  #fff9c6;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col0 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col1 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col2 {
#             background-color:  #e6f5e1;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ba44dd36_dc73_11ea_a879_f49634a60198row9_col5 {
#             background-color:  #feeca4;
#             color:  #000000;

# %%
#collapse-hide
#data = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv", 
#                   error_bad_lines=False)
data = df_deaths.copy()
data = data.drop(columns=["Lat", "Long"])
data = data.melt(id_vars= ["state", "country", "continent"])
data = pd.DataFrame(data.groupby(['country', "variable"]).sum())
data.reset_index(inplace=True)  
data = data.rename(columns={"country": "location", "variable": "date", "value": "total_cases"})
data['date'] = pd.to_datetime(data.date)
data = data.sort_values(by = "date")
data.loc[data.location == "US","location"] = "United States"
data.loc[data.location == "Korea, South","location"] = "South Korea"
data.head()
# Out:
#           location       date  total_cases
# 0      Afghanistan 2020-01-22            0
# 36946      Vietnam 2020-01-22            0
# 29232   San Marino 2020-01-22            0
# 1421       Armenia 2020-01-22            0
# 20300    Lithuania 2020-01-22            0

# %%
#collapse-hide
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_countries_cases.sort_values('Confirmed')["Confirmed"].index[-10:],df_countries_cases.sort_values('Confirmed')["Confirmed"].values[-10:],color="darkcyan")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Confirmed Cases",fontsize=18)
plt.title("Top 10 Countries (Confirmed Cases)",fontsize=20)
plt.grid(alpha=0.3)
#plt.savefig(out+'Top 10 Countries (Confirmed Cases).png')

# %%
#collapse-hide
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_countries_cases.sort_values('Deaths')["Deaths"].index[-10:],df_countries_cases.sort_values('Deaths')["Deaths"].values[-10:],color="crimson")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Deaths Cases",fontsize=18)
plt.title("Top 10 Countries (Deaths Cases)",fontsize=20)
plt.grid(alpha=0.3,which='both')
#plt.savefig(out+'Top 10 Countries (Deaths Cases).png')

# %%
#collapse-hide
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_countries_cases.sort_values('Active')["Active"].index[-10:],df_countries_cases.sort_values('Active')["Active"].values[-10:],color="darkorange")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Active Cases",fontsize=18)
plt.title("Top 10 Countries (Active Cases)",fontsize=20)
plt.grid(alpha=0.3,which='both')
#plt.savefig(out+'Top 10 Countries (Active Cases).png')

# %%
#collapse-hide
f = plt.figure(figsize=(10,5))
f.add_subplot(111)

plt.axes(axisbelow=True)
plt.barh(df_countries_cases.sort_values('Recovered')["Recovered"].index[-10:],df_countries_cases.sort_values('Recovered')["Recovered"].values[-10:],color="limegreen")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Recovered Cases",fontsize=18)
plt.title("Top 10 Countries (Recovered Cases)",fontsize=20)
plt.grid(alpha=0.3,which='both')
#plt.savefig(out+'Top 10 Countries (Recovered Cases).png')
